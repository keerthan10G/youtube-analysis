# %% [markdown]
# YOUTUBE DATASET ANALYSIS

# %%
import pandas as pd

from matplotlib import pyplot as pl
import numpy as np

df=pd.read_csv("C:\kgrpy\jupyternote\python1\youtube_data.csv",encoding='latin1')

# %% [markdown]
# we used encoding because of th special characters present in the dataset

# %%
df.head(4)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# ...

# %%
df.tail(4)
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation channel_type  ...  subscribers_for_last_30_days  \
# 991           IN        Games  ...                      300000.0
# 992           GB        Games  ...                        1000.0
# 993           SE        Games  ...                      100000.0
# ...

# %%
df.shape
# Out:
# (995, 28)

# %%
df.size
# Out:
# 27860

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df[df.duplicated()==True].sum()
# Out:
# rank                                       0.0
# Youtuber                                   0.0
# subscribers                                0.0
# video views                                0.0
# category                                   0.0
# Title                                      0.0
# uploads                                    0.0
# Country                                    0.0
# Abbreviation                               0.0
# channel_type                               0.0
# video_views_rank                           0.0
# country_rank                               0.0
# channel_type_rank                          0.0
# video_views_for_the_last_30_days           0.0
# lowest_monthly_earnings                    0.0
# highest_monthly_earnings                   0.0
# lowest_yearly_earnings                     0.0
# highest_yearly_earnings                    0.0
# subscribers_for_last_30_days               0.0
# created_year                               0.0
# ...

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
v=df.Population.mean()
df['Population'].fillna(value=v).sample(10)
# Out:
# 95     1.366418e+09
# 884    1.366418e+09
# 91     3.282395e+08
# 304    4.303873e+08
# 301    1.260140e+08
# 41     3.282395e+08
# 342    3.282395e+08
# 25     1.366418e+09
# 144    1.366418e+09
# 72     3.282395e+08
# Name: Population, dtype: float64

# %% [markdown]
# for this we can use fillna function and attribute is used is method or value but let use method

# %%
df.fillna(method='ffill',inplace=True)
df.isna().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               0
# created_month                              0
# ...

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.Country.nunique()
# Out:
# 49

# %%
df.Country.unique()
# Out:
# array(['India', 'United States', 'Japan', 'Russia', 'South Korea',
#        'United Kingdom', 'Canada', 'Brazil', 'Argentina', 'Chile', 'Cuba',
#        'El Salvador', 'Pakistan', 'Philippines', 'Thailand', 'Colombia',
#        'Barbados', 'Mexico', 'United Arab Emirates', 'Spain',
#        'Saudi Arabia', 'Indonesia', 'Turkey', 'Venezuela', 'Kuwait',
#        'Jordan', 'Netherlands', 'Singapore', 'Australia', 'Italy',
#        'Germany', 'France', 'Sweden', 'Afghanistan', 'Ukraine', 'Latvia',
#        'Switzerland', 'Vietnam', 'Malaysia', 'China', 'Iraq', 'Egypt',
#        'Andorra', 'Ecuador', 'Morocco', 'Peru', 'Bangladesh', 'Finland',
#        'Samoa'], dtype=object)

# %%
'''df['Population']=df.astype('int')
pl.plot(df.Population,df['Country'])'''
# Out:
# "df['Population']=df.astype('int')\npl.plot(df.Population,df['Country'])"

# %%
df.uploads.isna().sum()
# Out:
# 0

# %%
'''l=['India','United States','Japan','Russia']
for i in df.Country:
    if i!=l:
        print("gh")
       
pl.scatter(df.rank,df[i])
pl.show()'''
# Out:
# 'l=[\'India\',\'United States\',\'Japan\',\'Russia\']\nfor i in df.Country:\n    if i!=l:\n        print("gh")\n       \npl.scatter(df.rank,df[i])\npl.show()'

# %%
df.Country.unique()
# Out:
# array(['India', 'United States', 'Japan', 'Russia', 'South Korea',
#        'United Kingdom', 'Canada', 'Brazil', 'Argentina', 'Chile', 'Cuba',
#        'El Salvador', 'Pakistan', 'Philippines', 'Thailand', 'Colombia',
#        'Barbados', 'Mexico', 'United Arab Emirates', 'Spain',
#        'Saudi Arabia', 'Indonesia', 'Turkey', 'Venezuela', 'Kuwait',
#        'Jordan', 'Netherlands', 'Singapore', 'Australia', 'Italy',
#        'Germany', 'France', 'Sweden', 'Afghanistan', 'Ukraine', 'Latvia',
#        'Switzerland', 'Vietnam', 'Malaysia', 'China', 'Iraq', 'Egypt',
#        'Andorra', 'Ecuador', 'Morocco', 'Peru', 'Bangladesh', 'Finland',
#        'Samoa'], dtype=object)

# %%
pl.figure(figsize=(30,8))
pl.bar(df.category,df.uploads)
pl.title("Category wise uploads",fontsize=45,color="#36de")

#pl.xticks(np.arange(0,300000,100000))
#pl.yticks(['music','shows'])
pl.show()

# %%
df.uploads.max()
# Out:
# 301308

# %%
pl.figure(figsize=(4,5),dpi=100)
pl.bar(df['category'].loc[df.category.isin(["Music","Shows"])],df['uploads'].loc[df.category.isin(["Music","Shows"])])
pl.ylabel("uploads")
pl.ylabel("Category")
pl.title("Music and Shows Category uploads",fontsize=15)
pl.show()
#pl.bar(df.category)

# %%
df['category'].loc[df.category.isin(["Music","Shows"])].shape

# %%
df['uploads'].loc[df.category.isin(["Music","Shows"])]

# %%
h=[34.5,78.9,23.4]
w=[56,76,66]
ax=pl.axes(projection="3d")

ax.plot(w,h,w,'r--*')
pl.show()

# %%
run=[12,13,14]
over=[1,2,3]
run1=[10,7,9]
over1=[1,2,3]
pl.plot(over,run,'r-*')
pl.plot(over1,run1,'g-+')
pl.yticks(np.arange(,max(run1)+1,1))
pl.show()

# %%
df.sample(7)

# %%
pl.figure(figsize=(6,8))
pl.bar(df.created_year.loc[df["created_year"]>=2006],df["video views"].loc[df["created_year"]>=2006])
pl.bar(df.created_year.loc[df["created_year"]>=2006],0)
pl.xticks(np.arange(2006,2023,2))
g=df["video views"].loc[df["created_year"]>=2006].max()
j=[]
n=np.arange(0,g,20000000000)
for i in n.astype(str):
    o=i+'b'
    j.append(o)
j1=pd.Series(j)
pl.yticks(j1)
pl.show()

# %%
h=df["video views"].loc[df["created_year"]>=2006].max()
np.arange(0,h,20000000000)

# %%
j=[]
n=np.arange(0,g,20000000000)
for i in n.astype(str):
    o=i+'b'
    j.append(o)

# %%
l=[45,67,89]
k=["p","u","k"]
exp=[0.01,0.01,0.01]
pl.figure(1)
pl.pie(l,labels=k,explode=exp,autopct='%.2f%%')
pl.figure(2)
pl.plot(l,k)
pl.show()

# %%
fig,axs=pl.subplots(1,3)
fig(figsize=(10,3))

# %%
df.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.loc[df["rank"]<=5]
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
pl.pie(df["video views"].loc[df["rank"]<=5],autopct="%.1f%%",explode=[0.01,0.09,0.01,0.01,0.01],pctdistance=.7,labels=["#rank1","#rank2","#rank3","#rank4","#rank5"])
pl.show()

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
l=[]
for i in range(0,5):
    l.append(0.05)
label=df.Youtuber.loc[df["rank"]<=5]
pl.pie(df.subscribers_for_last_30_days.loc[df["rank"]<=5],autopct='%.1f%%',pctdistance=0.7,explode=l,labels=o)
pl.show()

# %%
pl.scatter(df.uploads.loc[df["rank"]<=10],df["Youtuber"].loc[df["rank"]<=10],label="uploads")
pl.grid(axis='y',alpha=0.3)
pl.legend()
#pl.scatter(df.Subscribers.loc[df["rank"]<=10],df["Youtuber"].loc[df["rank"]<=10])
pl.show()

# %% [markdown]
# Report:

# %% [markdown]
# Most for yoube are gained from people and blogs,news and blogs Categories
# most views channel is T-series which is indian based youtube channel,
# but as per data MrBeast youtube channel as got more number of subscribers in lasts 30 days
